# %%
import os
import json
import networkx as nx
import matplotlib.pyplot as plt
from typing import List, Dict, Any
import pandas as pd
from langchain.document_loaders import PyPDFLoader
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains.llm import LLMChain
from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter

os.environ["OPENAI_API_KEY"] = "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"

# %%
file_paths = [
        "/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf",
        "/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/Apple_Environmental_Progress_Report_2024.pdf",
        "/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/Apple-Supply-Chain-2025-Progress-Report.pdf"
]

# %%
from knowledge_graph import load_documents
documents = load_documents(file_paths)
# Out:
# incorrect startxref pointer(1)
# parsing for Object Streams
# found 0 objects within Object(14266,0) whereas 100 expected
# found 0 objects within Object(14267,0) whereas 100 expected
# found 0 objects within Object(14268,0) whereas 100 expected
# found 0 objects within Object(14269,0) whereas 100 expected
# found 0 objects within Object(14270,0) whereas 100 expected
# found 0 objects within Object(14271,0) whereas 100 expected
# found 0 objects within Object(14272,0) whereas 100 expected
# found 0 objects within Object(14273,0) whereas 100 expected
# found 0 objects within Object(14274,0) whereas 100 expected
# found 0 objects within Object(14275,0) whereas 100 expected
# found 0 objects within Object(14276,0) whereas 100 expected
# found 0 objects within Object(14277,0) whereas 100 expected
# found 0 objects within Object(14278,0) whereas 100 expected
# found 0 objects within Object(14279,0) whereas 100 expected
# found 0 objects within Object(14280,0) whereas 100 expected
# found 0 objects within Object(14281,0) whereas 100 expected
# found 0 objects within Object(14282,0) whereas 100 expected
# found 0 objects within Object(14283,0) whereas 100 expected
# found 0 objects within Object(14284,0) whereas 100 expected
# found 0 objects within Object(14285,0) whereas 100 expected
# found 0 objects within Object(14286,0) whereas 100 expected
# found 0 objects within Object(14287,0) whereas 100 expected
# found 0 objects within Object(14288,0) whereas 100 expected
# found 0 objects within Object(14289,0) whereas 100 expected
# found 0 objects within Object(14290,0) whereas 100 expected
# found 0 objects within Object(14291,0) whereas 100 expected
# found 0 objects within Object(14292,0) whereas 100 expected
# found 0 objects within Object(14293,0) whereas 100 expected
# found 0 objects within Object(14294,0) whereas 100 expected
# found 0 objects within Object(14295,0) whereas 100 expected
# found 0 objects within Object(14296,0) whereas 100 expected
# found 0 objects within Object(14297,0) whereas 100 expected
# found 0 objects within Object(14298,0) whereas 100 expected
# found 0 objects within Object(14299,0) whereas 100 expected
# found 0 objects within Object(14300,0) whereas 100 expected
# found 0 objects within Object(14301,0) whereas 100 expected
# found 0 objects within Object(14302,0) whereas 100 expected
# found 0 objects within Object(14303,0) whereas 100 expected
# found 0 objects within Object(14304,0) whereas 100 expected
# found 0 objects within Object(14305,0) whereas 100 expected
# found 0 objects within Object(14306,0) whereas 100 expected
# found 0 objects within Object(14307,0) whereas 100 expected
# found 0 objects within Object(14308,0) whereas 100 expected
# found 0 objects within Object(14309,0) whereas 100 expected
# found 0 objects within Object(14310,0) whereas 100 expected
# found 0 objects within Object(14311,0) whereas 100 expected
# found 0 objects within Object(14312,0) whereas 100 expected
# found 0 objects within Object(14313,0) whereas 100 expected
# found 0 objects within Object(14314,0) whereas 100 expected
# found 0 objects within Object(14315,0) whereas 100 expected
# found 0 objects within Object(14316,0) whereas 100 expected
# found 0 objects within Object(14317,0) whereas 100 expected
# found 0 objects within Object(14318,0) whereas 100 expected
# found 0 objects within Object(14319,0) whereas 100 expected
# found 0 objects within Object(14320,0) whereas 100 expected
# found 0 objects within Object(14321,0) whereas 100 expected
# found 0 objects within Object(14322,0) whereas 100 expected
# found 0 objects within Object(14323,0) whereas 100 expected
# found 0 objects within Object(14324,0) whereas 100 expected
# found 0 objects within Object(14325,0) whereas 100 expected
# found 0 objects within Object(14326,0) whereas 100 expected
# found 0 objects within Object(14327,0) whereas 100 expected
# found 0 objects within Object(14328,0) whereas 100 expected
# found 0 objects within Object(14329,0) whereas 100 expected
# found 0 objects within Object(14330,0) whereas 100 expected
# found 0 objects within Object(14331,0) whereas 100 expected
# found 0 objects within Object(14332,0) whereas 100 expected
# found 0 objects within Object(14333,0) whereas 100 expected
# found 0 objects within Object(14334,0) whereas 100 expected
# found 0 objects within Object(14335,0) whereas 100 expected
# found 0 objects within Object(14336,0) whereas 100 expected
# found 0 objects within Object(14337,0) whereas 100 expected
# found 0 objects within Object(14338,0) whereas 100 expected
# found 0 objects within Object(14339,0) whereas 100 expected
# found 0 objects within Object(14340,0) whereas 100 expected
# found 0 objects within Object(14341,0) whereas 100 expected
# found 0 objects within Object(14342,0) whereas 100 expected
# found 0 objects within Object(14343,0) whereas 100 expected
# found 0 objects within Object(14344,0) whereas 100 expected
# found 0 objects within Object(14345,0) whereas 100 expected
# found 0 objects within Object(14346,0) whereas 100 expected
# found 0 objects within Object(14347,0) whereas 100 expected
# found 0 objects within Object(14348,0) whereas 100 expected
# found 0 objects within Object(14349,0) whereas 100 expected
# found 0 objects within Object(14350,0) whereas 100 expected
# found 0 objects within Object(14351,0) whereas 100 expected
# found 0 objects within Object(14352,0) whereas 100 expected
# found 0 objects within Object(14353,0) whereas 100 expected
# found 0 objects within Object(14354,0) whereas 100 expected
# found 0 objects within Object(14355,0) whereas 100 expected
# found 0 objects within Object(14356,0) whereas 100 expected
# found 0 objects within Object(14357,0) whereas 100 expected
# found 0 objects within Object(14358,0) whereas 100 expected
# found 0 objects within Object(14359,0) whereas 100 expected
# found 0 objects within Object(14360,0) whereas 100 expected
# found 0 objects within Object(14361,0) whereas 100 expected
# found 0 objects within Object(14362,0) whereas 100 expected
# found 0 objects within Object(14363,0) whereas 100 expected
# found 0 objects within Object(14364,0) whereas 100 expected
# found 0 objects within Object(14365,0) whereas 100 expected
# found 0 objects within Object(14366,0) whereas 100 expected
# found 0 objects within Object(14367,0) whereas 100 expected
# found 0 objects within Object(14368,0) whereas 100 expected
# found 0 objects within Object(14369,0) whereas 100 expected
# found 0 objects within Object(14370,0) whereas 100 expected
# found 0 objects within Object(14371,0) whereas 100 expected
# found 0 objects within Object(14372,0) whereas 100 expected
# found 0 objects within Object(14373,0) whereas 100 expected
# found 0 objects within Object(14374,0) whereas 100 expected
# found 0 objects within Object(14375,0) whereas 100 expected
# found 0 objects within Object(14376,0) whereas 100 expected
# found 0 objects within Object(14377,0) whereas 100 expected
# found 0 objects within Object(14378,0) whereas 100 expected
# found 0 objects within Object(14379,0) whereas 100 expected
# found 0 objects within Object(14380,0) whereas 100 expected
# found 0 objects within Object(14381,0) whereas 100 expected
# found 0 objects within Object(14382,0) whereas 100 expected
# found 0 objects within Object(14383,0) whereas 100 expected
# found 0 objects within Object(14384,0) whereas 100 expected
# found 0 objects within Object(14385,0) whereas 100 expected
# found 0 objects within Object(14386,0) whereas 100 expected
# found 0 objects within Object(14387,0) whereas 100 expected
# found 0 objects within Object(14388,0) whereas 100 expected
# found 0 objects within Object(14389,0) whereas 100 expected
# found 0 objects within Object(14390,0) whereas 100 expected
# found 0 objects within Object(14391,0) whereas 100 expected
# found 0 objects within Object(14392,0) whereas 100 expected
# found 0 objects within Object(14393,0) whereas 100 expected
# found 0 objects within Object(14394,0) whereas 100 expected
# found 0 objects within Object(14395,0) whereas 100 expected
# found 0 objects within Object(14396,0) whereas 100 expected
# found 0 objects within Object(14397,0) whereas 100 expected
# found 0 objects within Object(14398,0) whereas 100 expected
# found 0 objects within Object(14399,0) whereas 100 expected
# found 0 objects within Object(14400,0) whereas 100 expected
# found 0 objects within Object(14401,0) whereas 100 expected
# found 0 objects within Object(14402,0) whereas 100 expected
# found 0 objects within Object(14403,0) whereas 100 expected
# found 0 objects within Object(14404,0) whereas 100 expected
# found 0 objects within Object(14405,0) whereas 100 expected
# found 0 objects within Object(14406,0) whereas 100 expected
# found 0 objects within Object(14407,0) whereas 100 expected
# found 0 objects within Object(14408,0) whereas 100 expected
# found 0 objects within Object(14409,0) whereas 100 expected
# found 0 objects within Object(14410,0) whereas 100 expected
# found 0 objects within Object(14411,0) whereas 100 expected
# found 0 objects within Object(14412,0) whereas 100 expected
# found 0 objects within Object(14413,0) whereas 100 expected
# found 0 objects within Object(14414,0) whereas 100 expected
# found 0 objects within Object(14415,0) whereas 100 expected
# found 0 objects within Object(14416,0) whereas 100 expected
# found 0 objects within Object(14417,0) whereas 100 expected
# found 0 objects within Object(14418,0) whereas 100 expected
# found 0 objects within Object(14419,0) whereas 100 expected
# found 0 objects within Object(14420,0) whereas 100 expected
# found 0 objects within Object(14421,0) whereas 100 expected
# found 0 objects within Object(14422,0) whereas 100 expected
# found 0 objects within Object(14423,0) whereas 100 expected
# found 0 objects within Object(14424,0) whereas 100 expected
# found 0 objects within Object(14425,0) whereas 100 expected
# found 0 objects within Object(14426,0) whereas 100 expected
# found 0 objects within Object(14427,0) whereas 100 expected
# found 0 objects within Object(14428,0) whereas 100 expected
# found 0 objects within Object(14429,0) whereas 100 expected
# found 0 objects within Object(14430,0) whereas 100 expected
# found 0 objects within Object(14431,0) whereas 100 expected
# found 0 objects within Object(14432,0) whereas 100 expected
# found 0 objects within Object(14433,0) whereas 100 expected
# found 0 objects within Object(14434,0) whereas 100 expected
# found 0 objects within Object(14435,0) whereas 100 expected
# found 0 objects within Object(14436,0) whereas 100 expected
# found 0 objects within Object(14437,0) whereas 100 expected
# found 0 objects within Object(14438,0) whereas 100 expected
# found 0 objects within Object(14439,0) whereas 100 expected
# found 0 objects within Object(14440,0) whereas 100 expected
# found 0 objects within Object(14441,0) whereas 100 expected
# found 0 objects within Object(14442,0) whereas 100 expected
# found 0 objects within Object(14443,0) whereas 100 expected
# found 0 objects within Object(14444,0) whereas 100 expected
# found 0 objects within Object(14445,0) whereas 100 expected
# found 0 objects within Object(14446,0) whereas 100 expected
# found 0 objects within Object(14447,0) whereas 100 expected
# found 0 objects within Object(14448,0) whereas 100 expected
# found 0 objects within Object(14449,0) whereas 100 expected
# found 0 objects within Object(14450,0) whereas 100 expected
# found 0 objects within Object(14451,0) whereas 100 expected
# found 0 objects within Object(14452,0) whereas 100 expected
# found 0 objects within Object(14453,0) whereas 100 expected
# found 0 objects within Object(14454,0) whereas 100 expected
# found 0 objects within Object(14455,0) whereas 100 expected
# found 0 objects within Object(14456,0) whereas 100 expected
# found 0 objects within Object(14457,0) whereas 100 expected
# found 0 objects within Object(14458,0) whereas 100 expected
# found 0 objects within Object(14459,0) whereas 100 expected
# found 0 objects within Object(14460,0) whereas 100 expected
# found 0 objects within Object(14461,0) whereas 100 expected
# found 0 objects within Object(14462,0) whereas 100 expected
# found 0 objects within Object(14463,0) whereas 100 expected
# found 0 objects within Object(14464,0) whereas 100 expected
# found 0 objects within Object(14465,0) whereas 100 expected
# found 0 objects within Object(14466,0) whereas 100 expected
# found 0 objects within Object(14467,0) whereas 100 expected
# found 0 objects within Object(14468,0) whereas 100 expected
# found 0 objects within Object(14469,0) whereas 43 expected

# %%
print(f"Loaded {len(documents)} documents.")
print(f"First document: {documents[5].page_content[:100]}...")
# Out:
# Loaded 291 documents.
# First document: The Company’s ability to compete successfully depends heavily on ensuring the continuing and timely ...

# %%
from knowledge_graph import split_documents

chunks = split_documents(documents)
print(f"Split into {len(chunks)} chunks.")
print(f"First chunk: {chunks[0].page_content[:100]}...")
# Out:
# Split into 550 chunks.
# First chunk: UNITED STATES
# SECURITIES AND EXCHANGE COMMISSION
# Washington, D.C. 20549
# FORM 10-K
# (Mark One)
# ☒    AN...

# %%
def extract_entities_and_relationships(chunk: Document):
    print(f"Processing chunk with metadata: {chunk.metadata}")
    llm = ChatOpenAI(temperature=0, model="gpt-4o-mini", openai_api_key=os.environ["OPENAI_API_KEY"])
    print("LLM initialized")
    prompt_template = """
    You are an expert in extracting structured information about Apple Inc. from documents.
    
    Extract entities and their relationships from the following text. Focus on:
    1. Apple and its business units
    2. Suppliers and manufacturing partners
    3. Products and components
    4. Geographic locations of operations
    5. Materials used in products
    6. Environmental initiatives
    7. Regulations and compliance
    
    TEXT:
    {text}
    
    SOURCE:
    {source}
    
    OUTPUT FORMAT:
    Return a JSON object with these arrays:
    1. "entities": List of entities found with their types and properties
    2. "relationships": List of relationships between entities with their types and properties
    
    Example:
    {{
        "entities": [
            {{"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {{"description": "Technology company"}}}},
            {{"id": "foxconn", "type": "Supplier", "name": "Foxconn", "properties": {{"description": "Manufacturing partner", "risk_level": "Medium"}}}}
        ],
        "relationships": [
            {{"source": "foxconn", "target": "apple", "type": "Supplies", "properties": {{"details": "Assembles iPhones", "dependency_level": "Critical"}}}}
        ]
    }}
    
    Return ONLY valid JSON:
    """
    
    prompt = ChatPromptTemplate.from_template(prompt_template)
    chain = prompt | llm
    
    print("Chain initialized")

    result = chain.invoke({"text": chunk.page_content, "source": chunk.metadata["source"]}).content
    print(f"LLM output: {result}")
    
    try:
        extracted_data = json.loads(result)
        
        if not isinstance(extracted_data, dict):
            print(f"Error: Expected a dictionary, got {type(extracted_data)}")
            return {"entities": [], "relationships": []}
            
        if "entities" not in extracted_data or "relationships" not in extracted_data:
            print(f"Error: Missing 'entities' or 'relationships' keys in the output")
            return {"entities": [], "relationships": []}
            
        valid_entities = []
        for entity in extracted_data.get("entities", []):
            if not isinstance(entity, dict):
                print(f"Warning: Expected entity to be a dict, got {type(entity)}")
                continue
                
            if "id" not in entity or "type" not in entity or "name" not in entity:
                print(f"Warning: Entity missing required fields: {entity}")
                continue
                
            if "properties" not in entity or not isinstance(entity["properties"], dict):
                entity["properties"] = {}
                
            valid_entities.append(entity)
            
        valid_relationships = []
        for rel in extracted_data.get("relationships", []):
            if not isinstance(rel, dict):
                print(f"Warning: Expected relationship to be a dict, got {type(rel)}")
                continue
                
            if "source" not in rel or "target" not in rel or "type" not in rel:
                print(f"Warning: Relationship missing required fields: {rel}")
                continue
                
            if "properties" not in rel or not isinstance(rel["properties"], dict):
                rel["properties"] = {}
                
            valid_relationships.append(rel)
            
        return {
            "entities": valid_entities,
            "relationships": valid_relationships
        }
        
    except json.JSONDecodeError:
        print(f"Error parsing LLM output as JSON: {result}")
        return {"entities": [], "relationships": []}

    
def process_all_chunks(chunks: List[Document]):
    print(f"Processing {len(chunks)} chunks")
    all_entities = {}
    all_relationships = []
    
    for i, chunk in enumerate(chunks):
        print(f"Processing chunk {i+1}/{len(chunks)}")
        extracted_data = extract_entities_and_relationships(chunk)
        
        print(f"Found {len(extracted_data['entities'])} entities and {len(extracted_data['relationships'])} relationships")

        
        for entity in extracted_data["entities"]:
            if not isinstance(entity, dict) or "id" not in entity:
                print(f"Warning: Skipping invalid entity: {entity}")
                continue
                
            entity_id = entity["id"]
            if entity_id not in all_entities:
                all_entities[entity_id] = entity
            else:
                if "properties" not in entity:
                    entity["properties"] = {}
                if "properties" not in all_entities[entity_id]:
                    all_entities[entity_id]["properties"] = {}
                all_entities[entity_id]["properties"].update(entity["properties"])
        
        for rel in extracted_data["relationships"]:
            if not isinstance(rel, dict) or "source" not in rel or "target" not in rel:
                print(f"Warning: Skipping invalid relationship: {rel}")
                continue
                
            all_relationships.append(rel)
            
        if i >= 30:
            print("Processed 30 chunks, stopping for now.")
            break
    
    entities_list = list(all_entities.values())
    
    return {
        "entities": entities_list,
        "relationships": all_relationships
    }

# %%
knowledge_graph = process_all_chunks(chunks)
# Out:
# Processing 550 chunks
# Processing chunk 1/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 0, 'page_label': '1'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {
#             "id": "apple",
#             "type": "Company",
#             "name": "Apple Inc.",
#             "properties": {
#                 "description": "Technology company",
#                 "fiscal_year_ended": "September 28, 2024",
#                 "headquarters": "One Apple Park Way, Cupertino, California 95014"
#             }
#         },
#         {
#             "id": "california",
#             "type": "GeographicLocation",
#             "name": "California",
#             "properties": {
#                 "description": "State of incorporation"
#             }
#         },
#         {
#             "id": "nasdaq",
#             "type": "StockExchange",
#             "name": "The Nasdaq Stock Market LLC",
#             "properties": {
#                 "description": "Stock exchange where Apple is listed"
#             }
#         },
#         {
#             "id": "common_stock",
#             "type": "FinancialInstrument",
#             "name": "Common Stock",
#             "properties": {
#                 "par_value": "$0.00001",
#                 "trading_symbol": "AAPL"
#             }
#         },
#         {
#             "id": "notes_due_2025",
#             "type": "FinancialInstrument",
#             "name": "0.000% Notes due 2025",
#             "properties": {}
#         },
#         {
#             "id": "notes_due_2026",
#             "type": "FinancialInstrument",
#             "name": "1.625% Notes due 2026",
#             "properties": {}
#         },
#         {
#             "id": "notes_due_2027",
#             "type": "FinancialInstrument",
#             "name": "2.000% Notes due 2027",
#             "properties": {}
#         },
#         {
#             "id": "notes_due_2029_1",
#             "type": "FinancialInstrument",
#             "name": "1.375% Notes due 2029",
#             "properties": {}
#         },
#         {
#             "id": "notes_due_2029_2",
#             "type": "FinancialInstrument",
#             "name": "3.050% Notes due 2029",
#             "properties": {}
#         },
#         {
#             "id": "notes_due_2031",
#             "type": "FinancialInstrument",
#             "name": "0.500% Notes due 2031",
#             "properties": {}
#         },
#         {
#             "id": "notes_due_2042",
#             "type": "FinancialInstrument",
#             "name": "3.600% Notes due 2042",
#             "properties": {}
#         }
#     ],
#     "relationships": [
#         {
#             "source": "apple",
#             "target": "california",
#             "type": "IncorporatedIn",
#             "properties": {
#                 "details": "Apple Inc. is incorporated in California"
#             }
#         },
#         {
#             "source": "common_stock",
#             "target": "apple",
#             "type": "ListedOn",
#             "properties": {
#                 "details": "Common Stock is listed on The Nasdaq Stock Market LLC"
#             }
#         },
#         {
#             "source": "notes_due_2025",
#             "target": "apple",
#             "type": "IssuedBy",
#             "properties": {
#                 "details": "0.000% Notes due 2025 are issued by Apple Inc."
#             }
#         },
#         {
#             "source": "notes_due_2026",
#             "target": "apple",
#             "type": "IssuedBy",
#             "properties": {
#                 "details": "1.625% Notes due 2026 are issued by Apple Inc."
#             }
#         },
#         {
#             "source": "notes_due_2027",
#             "target": "apple",
#             "type": "IssuedBy",
#             "properties": {
#                 "details": "2.000% Notes due 2027 are issued by Apple Inc."
#             }
#         },
#         {
#             "source": "notes_due_2029_1",
#             "target": "apple",
#             "type": "IssuedBy",
#             "properties": {
#                 "details": "1.375% Notes due 2029 are issued by Apple Inc."
#             }
#         },
#         {
#             "source": "notes_due_2029_2",
#             "target": "apple",
#             "type": "IssuedBy",
#             "properties": {
#                 "details": "3.050% Notes due 2029 are issued by Apple Inc."
#             }
#         },
#         {
#             "source": "notes_due_2031",
#             "target": "apple",
#             "type": "IssuedBy",
#             "properties": {
#                 "details": "0.500% Notes due 2031 are issued by Apple Inc."
#             }
#         },
#         {
#             "source": "notes_due_2042",
#             "target": "apple",
#             "type": "IssuedBy",
#             "properties": {
#                 "details": "3.600% Notes due 2042 are issued by Apple Inc."
#             }
#         }
#     ]
# }
# Found 11 entities and 9 relationships
# Processing chunk 2/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 0, 'page_label': '1'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [],
#     "relationships": []
# }
# Found 0 entities and 0 relationships
# Processing chunk 3/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 1, 'page_label': '2'}
# LLM initialized
# Chain initialized
# LLM output: ```json
# {
#     "entities": [
#         {
#             "id": "apple",
#             "type": "Company",
#             "name": "Apple Inc.",
#             "properties": {
#                 "description": "Technology company",
#                 "filer_status": "Large accelerated filer"
#             }
#         }
#     ],
#     "relationships": []
# }
# ```
# Error parsing LLM output as JSON: ```json
# {
#     "entities": [
#         {
#             "id": "apple",
#             "type": "Company",
#             "name": "Apple Inc.",
#             "properties": {
#                 "description": "Technology company",
#                 "filer_status": "Large accelerated filer"
#             }
#         }
#     ],
#     "relationships": []
# }
# ```
# Found 0 entities and 0 relationships
# Processing chunk 4/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 1, 'page_label': '2'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [],
#     "relationships": []
# }
# Found 0 entities and 0 relationships
# Processing chunk 5/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 1, 'page_label': '2'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company", "fiscal_quarter_revenue": "$2,628,553,000,000", "shares_outstanding": "15,115,823,000"}},
#         {"id": "sec", "type": "Regulatory Body", "name": "U.S. Securities and Exchange Commission", "properties": {"description": "Regulatory authority overseeing securities transactions"}},
#         {"id": "proxy_statement", "type": "Document", "name": "Definitive Proxy Statement", "properties": {"description": "Document related to annual meeting of shareholders", "filing_deadline": "120 days after fiscal year end"}}
#     ],
#     "relationships": [
#         {"source": "apple", "target": "sec", "type": "Complies With", "properties": {"details": "Files annual reports and proxy statements"}},
#         {"source": "apple", "target": "proxy_statement", "type": "Incorporates", "properties": {"details": "Incorporated by reference in annual report"}}
#     ]
# }
# Found 3 entities and 2 relationships
# Processing chunk 6/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 2, 'page_label': '3'}
# LLM initialized
# Chain initialized
# LLM output: ```json
# {
#     "entities": [
#         {
#             "id": "apple",
#             "type": "Company",
#             "name": "Apple Inc.",
#             "properties": {
#                 "description": "Technology company",
#                 "fiscal_year_ended": "September 28, 2024"
#             }
#         },
#         {
#             "id": "business_units",
#             "type": "Business Unit",
#             "name": "Various Business Units",
#             "properties": {
#                 "description": "Includes hardware, software, and services"
#             }
#         },
#         {
#             "id": "suppliers",
#             "type": "Supplier",
#             "name": "Various Suppliers",
#             "properties": {
#                 "description": "Manufacturing partners and component suppliers"
#             }
#         },
#         {
#             "id": "products",
#             "type": "Product",
#             "name": "Apple Products",
#             "properties": {
#                 "description": "Includes iPhones, iPads, Macs, and services"
#             }
#         },
#         {
#             "id": "geographic_locations",
#             "type": "Geographic Location",
#             "name": "Global Operations",
#             "properties": {
#                 "description": "Operations in various countries"
#             }
#         },
#         {
#             "id": "materials",
#             "type": "Material",
#             "name": "Various Materials",
#             "properties": {
#                 "description": "Materials used in product manufacturing"
#             }
#         },
#         {
#             "id": "environmental_initiatives",
#             "type": "Initiative",
#             "name": "Environmental Initiatives",
#             "properties": {
#                 "description": "Efforts to reduce environmental impact"
#             }
#         },
#         {
#             "id": "regulations",
#             "type": "Regulation",
#             "name": "Compliance Regulations",
#             "properties": {
#                 "description": "Regulations governing operations and compliance"
#             }
#         }
#     ],
#     "relationships": [
#         {
#             "source": "apple",
#             "target": "business_units",
#             "type": "Operates",
#             "properties": {
#                 "details": "Apple operates through various business units"
#             }
#         },
#         {
#             "source": "suppliers",
#             "target": "apple",
#             "type": "Supplies",
#             "properties": {
#                 "details": "Suppliers provide components and manufacturing services"
#             }
#         },
#         {
#             "source": "products",
#             "target": "apple",
#             "type": "Offers",
#             "properties": {
#                 "details": "Apple offers a range of products and services"
#             }
#         },
#         {
#             "source": "geographic_locations",
#             "target": "apple",
#             "type": "Operates In",
#             "properties": {
#                 "details": "Apple has operations in multiple geographic locations"
#             }
#         },
#         {
#             "source": "materials",
#             "target": "products",
#             "type": "Used In",
#             "properties": {
#                 "details": "Materials are used in the manufacturing of Apple products"
#             }
#         },
#         {
#             "source": "environmental_initiatives",
#             "target": "apple",
#             "type": "Supports",
#             "properties": {
#                 "details": "Apple supports various environmental initiatives"
#             }
#         },
#         {
#             "source": "regulations",
#             "target": "apple",
#             "type": "Complies With",
#             "properties": {
#                 "details": "Apple complies with relevant regulations"
#             }
#         }
#     ]
# }
# ```
# Error parsing LLM output as JSON: ```json
# {
#     "entities": [
#         {
#             "id": "apple",
#             "type": "Company",
#             "name": "Apple Inc.",
#             "properties": {
#                 "description": "Technology company",
#                 "fiscal_year_ended": "September 28, 2024"
#             }
#         },
#         {
#             "id": "business_units",
#             "type": "Business Unit",
#             "name": "Various Business Units",
#             "properties": {
#                 "description": "Includes hardware, software, and services"
#             }
#         },
#         {
#             "id": "suppliers",
#             "type": "Supplier",
#             "name": "Various Suppliers",
#             "properties": {
#                 "description": "Manufacturing partners and component suppliers"
#             }
#         },
#         {
#             "id": "products",
#             "type": "Product",
#             "name": "Apple Products",
#             "properties": {
#                 "description": "Includes iPhones, iPads, Macs, and services"
#             }
#         },
#         {
#             "id": "geographic_locations",
#             "type": "Geographic Location",
#             "name": "Global Operations",
#             "properties": {
#                 "description": "Operations in various countries"
#             }
#         },
#         {
#             "id": "materials",
#             "type": "Material",
#             "name": "Various Materials",
#             "properties": {
#                 "description": "Materials used in product manufacturing"
#             }
#         },
#         {
#             "id": "environmental_initiatives",
#             "type": "Initiative",
#             "name": "Environmental Initiatives",
#             "properties": {
#                 "description": "Efforts to reduce environmental impact"
#             }
#         },
#         {
#             "id": "regulations",
#             "type": "Regulation",
#             "name": "Compliance Regulations",
#             "properties": {
#                 "description": "Regulations governing operations and compliance"
#             }
#         }
#     ],
#     "relationships": [
#         {
#             "source": "apple",
#             "target": "business_units",
#             "type": "Operates",
#             "properties": {
#                 "details": "Apple operates through various business units"
#             }
#         },
#         {
#             "source": "suppliers",
#             "target": "apple",
#             "type": "Supplies",
#             "properties": {
#                 "details": "Suppliers provide components and manufacturing services"
#             }
#         },
#         {
#             "source": "products",
#             "target": "apple",
#             "type": "Offers",
#             "properties": {
#                 "details": "Apple offers a range of products and services"
#             }
#         },
#         {
#             "source": "geographic_locations",
#             "target": "apple",
#             "type": "Operates In",
#             "properties": {
#                 "details": "Apple has operations in multiple geographic locations"
#             }
#         },
#         {
#             "source": "materials",
#             "target": "products",
#             "type": "Used In",
#             "properties": {
#                 "details": "Materials are used in the manufacturing of Apple products"
#             }
#         },
#         {
#             "source": "environmental_initiatives",
#             "target": "apple",
#             "type": "Supports",
#             "properties": {
#                 "details": "Apple supports various environmental initiatives"
#             }
#         },
#         {
#             "source": "regulations",
#             "target": "apple",
#             "type": "Complies With",
#             "properties": {
#                 "details": "Apple complies with relevant regulations"
#             }
#         }
#     ]
# }
# ```
# Found 0 entities and 0 relationships
# Processing chunk 7/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 3, 'page_label': '4'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company"}},
#         {"id": "form_10k", "type": "Document", "name": "Annual Report on Form 10-K", "properties": {"description": "Annual financial report", "year": 2024}},
#         {"id": "macroeconomic_conditions", "type": "Concept", "name": "Macroeconomic Conditions", "properties": {"description": "Economic factors affecting business"}},
#         {"id": "risk_factors", "type": "Section", "name": "Risk Factors", "properties": {"description": "Potential risks affecting performance"}}
#     ],
#     "relationships": [
#         {"source": "form_10k", "target": "apple", "type": "Reports", "properties": {"details": "Annual financial performance report"}},
#         {"source": "form_10k", "target": "macroeconomic_conditions", "type": "Discusses", "properties": {"details": "Impact on business operations"}},
#         {"source": "form_10k", "target": "risk_factors", "type": "Includes", "properties": {"details": "Factors that may affect future performance"}}
#     ]
# }
# Found 4 entities and 3 relationships
# Processing chunk 8/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 3, 'page_label': '4'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {
#             "id": "apple",
#             "type": "Company",
#             "name": "Apple Inc.",
#             "properties": {
#                 "description": "Technology company",
#                 "fiscal_year_end": "Last Saturday of September"
#             }
#         },
#         {
#             "id": "iphone",
#             "type": "Product",
#             "name": "iPhone",
#             "properties": {
#                 "description": "Line of smartphones",
#                 "operating_system": "iOS",
#                 "models": ["iPhone 16 Pro", "iPhone 16", "iPhone 15", "iPhone 14", "iPhone SE"]
#             }
#         },
#         {
#             "id": "mac",
#             "type": "Product",
#             "name": "Mac",
#             "properties": {
#                 "description": "Line of personal computers",
#                 "operating_system": "macOS",
#                 "models": ["MacBook Air", "MacBook Pro", "iMac", "Mac mini", "Mac Studio", "Mac Pro"]
#             }
#         },
#         {
#             "id": "ipad",
#             "type": "Product",
#             "name": "iPad",
#             "properties": {
#                 "description": "Line of multipurpose tablets",
#                 "operating_system": "iPadOS",
#                 "models": ["iPad Pro"]
#             }
#         }
#     ],
#     "relationships": []
# }
# Found 4 entities and 0 relationships
# Processing chunk 9/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 3, 'page_label': '4'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company"}},
#         {"id": "ipad", "type": "Product", "name": "iPad", "properties": {"description": "Line of multipurpose tablets", "operating_system": "iPadOS"}},
#         {"id": "ipad_pro", "type": "Product", "name": "iPad Pro", "properties": {"description": "High-end model of iPad"}},
#         {"id": "ipad_air", "type": "Product", "name": "iPad Air", "properties": {"description": "Lightweight model of iPad"}},
#         {"id": "ipad_mini", "type": "Product", "name": "iPad mini", "properties": {"description": "Compact model of iPad"}},
#         {"id": "wearables", "type": "Business Unit", "name": "Wearables", "properties": {"description": "Includes smartwatches and headphones"}},
#         {"id": "apple_watch", "type": "Product", "name": "Apple Watch", "properties": {"description": "Line of smartwatches", "operating_system": "watchOS"}},
#         {"id": "apple_watch_ultra_2", "type": "Product", "name": "Apple Watch Ultra 2", "properties": {"description": "Premium smartwatch model"}},
#         {"id": "apple_watch_series_10", "type": "Product", "name": "Apple Watch Series 10", "properties": {"description": "Latest series of Apple Watch"}},
#         {"id": "apple_watch_se", "type": "Product", "name": "Apple Watch SE", "properties": {"description": "Affordable smartwatch model"}},
#         {"id": "airpods", "type": "Product", "name": "AirPods", "properties": {"description": "Wireless headphones"}},
#         {"id": "airpods_pro", "type": "Product", "name": "AirPods Pro", "properties": {"description": "Premium wireless headphones"}},
#         {"id": "airpods_max", "type": "Product", "name": "AirPods Max", "properties": {"description": "Over-ear wireless headphones"}},
#         {"id": "beats", "type": "Product", "name": "Beats", "properties": {"description": "Line of headphones"}},
#         {"id": "apple_vision_pro", "type": "Product", "name": "Apple Vision Pro", "properties": {"description": "First spatial computer", "operating_system": "visionOS"}},
#         {"id": "home", "type": "Business Unit", "name": "Home", "properties": {"description": "Includes media streaming and smart speakers"}},
#         {"id": "apple_tv", "type": "Product", "name": "Apple TV", "properties": {"description": "Media streaming and gaming device", "operating_system": "tvOS"}},
#         {"id": "homepod", "type": "Product", "name": "HomePod", "properties": {"description": "High-fidelity wireless smart speaker"}},
#         {"id": "homepod_mini", "type": "Product", "name": "HomePod mini", "properties": {"description": "Compact version of HomePod"}},
#         {"id": "accessories", "type": "Business Unit", "name": "Accessories", "properties": {"description": "Includes Apple-branded and third-party accessories"}}
#     ],
#     "relationships": [
#         {"source": "ipad", "target": "apple", "type": "Produces", "properties": {"details": "Part of Apple's product line"}},
#         {"source": "ipad_pro", "target": "ipad", "type": "Subcategory", "properties": {"details": "High-end model of iPad"}},
#         {"source": "ipad_air", "target": "ipad", "type": "Subcategory", "properties": {"details": "Lightweight model of iPad"}},
#         {"source": "ipad_mini", "target": "ipad", "type": "Subcategory", "properties": {"details": "Compact model of iPad"}},
#         {"source": "wearables", "target": "apple", "type": "Produces", "properties": {"details": "Includes smartwatches and headphones"}},
#         {"source": "apple_watch", "target": "wearables", "type": "Subcategory", "properties": {"details": "Line of smartwatches"}},
#         {"source": "apple_watch_ultra_2", "target": "apple_watch", "type": "Subcategory", "properties": {"details": "Premium smartwatch model"}},
#         {"source": "apple_watch_series_10", "target": "apple_watch", "type": "Subcategory", "properties": {"details": "Latest series of Apple Watch"}},
#         {"source": "apple_watch_se", "target": "apple_watch", "type": "Subcategory", "properties": {"details": "Affordable smartwatch model"}},
#         {"source": "airpods", "target": "wearables", "type": "Subcategory", "properties": {"details": "Wireless headphones"}},
#         {"source": "airpods_pro", "target": "airpods", "type": "Subcategory", "properties": {"details": "Premium wireless headphones"}},
#         {"source": "airpods_max", "target": "airpods", "type": "Subcategory", "properties": {"details": "Over-ear wireless headphones"}},
#         {"source": "beats", "target": "wearables", "type": "Subcategory", "properties": {"details": "Line of headphones"}},
#         {"source": "apple_vision_pro", "target": "wearables", "type": "Produces", "properties": {"details": "First spatial computer"}},
#         {"source": "home", "target": "apple", "type": "Produces", "properties": {"details": "Includes media streaming and smart speakers"}},
#         {"source": "apple_tv", "target": "home", "type": "Subcategory", "properties": {"details": "Media streaming and gaming device"}},
#         {"source": "homepod", "target": "home", "type": "Subcategory", "properties": {"details": "High-fidelity wireless smart speaker"}},
#         {"source": "homepod_mini", "target": "home", "type": "Subcategory", "properties": {"details": "Compact version of HomePod"}},
#         {"source": "accessories", "target": "apple", "type": "Produces", "properties": {"details": "Includes Apple-branded and third-party accessories"}}
#     ]
# }
# Found 20 entities and 19 relationships
# Processing chunk 10/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 4, 'page_label': '5'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {
#             "id": "apple",
#             "type": "Company",
#             "name": "Apple Inc.",
#             "properties": {
#                 "description": "Technology company",
#                 "business_units": [
#                     "Advertising",
#                     "AppleCare",
#                     "Cloud Services",
#                     "Digital Content",
#                     "Payment Services"
#                 ]
#             }
#         },
#         {
#             "id": "applecare",
#             "type": "Business Unit",
#             "name": "AppleCare",
#             "properties": {
#                 "description": "Portfolio of fee-based service and support products"
#             }
#         },
#         {
#             "id": "cloud_services",
#             "type": "Business Unit",
#             "name": "Cloud Services",
#             "properties": {
#                 "description": "Stores and keeps customers’ content up-to-date across devices"
#             }
#         },
#         {
#             "id": "digital_content",
#             "type": "Business Unit",
#             "name": "Digital Content",
#             "properties": {
#                 "description": "Platforms for discovering and downloading applications and digital content"
#             }
#         },
#         {
#             "id": "payment_services",
#             "type": "Business Unit",
#             "name": "Payment Services",
#             "properties": {
#                 "description": "Includes Apple Card and Apple Pay"
#             }
#         },
#         {
#             "id": "apple_arcade",
#             "type": "Product",
#             "name": "Apple Arcade",
#             "properties": {
#                 "description": "Game subscription service"
#             }
#         },
#         {
#             "id": "apple_fitness",
#             "type": "Product",
#             "name": "Apple Fitness+",
#             "properties": {
#                 "description": "Personalized fitness service"
#             }
#         },
#         {
#             "id": "apple_music",
#             "type": "Product",
#             "name": "Apple Music",
#             "properties": {
#                 "description": "Curated listening experience with on-demand radio stations"
#             }
#         },
#         {
#             "id": "apple_news",
#             "type": "Product",
#             "name": "Apple News+",
#             "properties": {
#                 "description": "Subscription news and magazine service"
#             }
#         },
#         {
#             "id": "apple_tv",
#             "type": "Product",
#             "name": "Apple TV+",
#             "properties": {
#                 "description": "Offers exclusive original content and live sports"
#             }
#         },
#         {
#             "id": "apple_card",
#             "type": "Product",
#             "name": "Apple Card",
#             "properties": {
#                 "description": "Co-branded credit card"
#             }
#         },
#         {
#             "id": "apple_pay",
#             "type": "Product",
#             "name": "Apple Pay",
#             "properties": {
#                 "description": "Cashless payment service"
#             }
#         }
#     ],
#     "relationships": [
#         {
#             "source": "apple",
#             "target": "applecare",
#             "type": "Offers",
#             "properties": {
#                 "details": "Provides priority access to technical support and repair services"
#             }
#         },
#         {
#             "source": "apple",
#             "target": "cloud_services",
#             "type": "Offers",
#             "properties": {
#                 "details": "Stores and keeps customers’ content up-to-date"
#             }
#         },
#         {
#             "source": "apple",
#             "target": "digital_content",
#             "type": "Operates",
#             "properties": {
#                 "details": "Platforms for discovering and downloading applications and digital content"
#             }
#         },
#         {
#             "source": "apple",
#             "target": "payment_services",
#             "type": "Offers",
#             "properties": {
#                 "details": "Includes Apple Card and Apple Pay"
#             }
#         },
#         {
#             "source": "digital_content",
#             "target": "apple_arcade",
#             "type": "Includes",
#             "properties": {
#                 "details": "Game subscription service"
#             }
#         },
#         {
#             "source": "digital_content",
#             "target": "apple_fitness",
#             "type": "Includes",
#             "properties": {
#                 "details": "Personalized fitness service"
#             }
#         },
#         {
#             "source": "digital_content",
#             "target": "apple_music",
#             "type": "Includes",
#             "properties": {
#                 "details": "Curated listening experience"
#             }
#         },
#         {
#             "source": "digital_content",
#             "target": "apple_news",
#             "type": "Includes",
#             "properties": {
#                 "details": "Subscription news and magazine service"
#             }
#         },
#         {
#             "source": "digital_content",
#             "target": "apple_tv",
#             "type": "Includes",
#             "properties": {
#                 "details": "Exclusive original content and live sports"
#             }
#         },
#         {
#             "source": "payment_services",
#             "target": "apple_card",
#             "type": "Includes",
#             "properties": {
#                 "details": "Co-branded credit card"
#             }
#         },
#         {
#             "source": "payment_services",
#             "target": "apple_pay",
#             "type": "Includes",
#             "properties": {
#                 "details": "Cashless payment service"
#             }
#         }
#     ]
# }
# Found 12 entities and 11 relationships
# Processing chunk 11/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 4, 'page_label': '5'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company offering payment services and consumer electronics"}},
#         {"id": "apple_card", "type": "Product", "name": "Apple Card", "properties": {"description": "Co-branded credit card"}},
#         {"id": "apple_pay", "type": "Product", "name": "Apple Pay", "properties": {"description": "Cashless payment service"}},
#         {"id": "americas", "type": "GeographicSegment", "name": "Americas", "properties": {"description": "Includes North and South America"}},
#         {"id": "europe", "type": "GeographicSegment", "name": "Europe", "properties": {"description": "Includes European countries, India, Middle East, and Africa"}},
#         {"id": "greater_china", "type": "GeographicSegment", "name": "Greater China", "properties": {"description": "Includes China mainland, Hong Kong, and Taiwan"}},
#         {"id": "rest_asia_pacific", "type": "GeographicSegment", "name": "Rest of Asia Pacific", "properties": {"description": "Includes Australia and other Asian countries"}},
#         {"id": "consumer_market", "type": "Market", "name": "Consumer Market", "properties": {"description": "Primary customer segment"}},
#         {"id": "education_market", "type": "Market", "name": "Education Market", "properties": {"description": "Primary customer segment"}},
#         {"id": "enterprise_market", "type": "Market", "name": "Enterprise Market", "properties": {"description": "Primary customer segment"}},
#         {"id": "government_market", "type": "Market", "name": "Government Market", "properties": {"description": "Primary customer segment"}},
#         {"id": "small_mid_business", "type": "Market", "name": "Small and Mid-sized Business Market", "properties": {"description": "Primary customer segment"}}
#     ],
#     "relationships": [
#         {"source": "apple", "target": "apple_card", "type": "Offers", "properties": {"details": "Co-branded credit card service"}},
#         {"source": "apple", "target": "apple_pay", "type": "Offers", "properties": {"details": "Cashless payment service"}},
#         {"source": "apple", "target": "americas", "type": "OperatesIn", "properties": {"details": "Geographic segment for operations"}},
#         {"source": "apple", "target": "europe", "type": "OperatesIn", "properties": {"details": "Geographic segment for operations"}},
#         {"source": "apple", "target": "greater_china", "type": "OperatesIn", "properties": {"details": "Geographic segment for operations"}},
#         {"source": "apple", "target": "rest_asia_pacific", "type": "OperatesIn", "properties": {"details": "Geographic segment for operations"}},
#         {"source": "apple", "target": "consumer_market", "type": "Serves", "properties": {"details": "Primary customer segment"}},
#         {"source": "apple", "target": "education_market", "type": "Serves", "properties": {"details": "Primary customer segment"}},
#         {"source": "apple", "target": "enterprise_market", "type": "Serves", "properties": {"details": "Primary customer segment"}},
#         {"source": "apple", "target": "government_market", "type": "Serves", "properties": {"details": "Primary customer segment"}},
#         {"source": "apple", "target": "small_mid_business", "type": "Serves", "properties": {"details": "Primary customer segment"}}
#     ]
# }
# Found 12 entities and 11 relationships
# Processing chunk 12/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 4, 'page_label': '5'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company"}},
#         {"id": "third_party_carriers", "type": "BusinessUnit", "name": "Third-party cellular network carriers", "properties": {"description": "Distribution channel"}},
#         {"id": "wholesalers", "type": "BusinessUnit", "name": "Wholesalers", "properties": {"description": "Distribution channel"}},
#         {"id": "retailers", "type": "BusinessUnit", "name": "Retailers", "properties": {"description": "Distribution channel"}},
#         {"id": "resellers", "type": "BusinessUnit", "name": "Resellers", "properties": {"description": "Distribution channel"}},
#         {"id": "net_sales", "type": "FinancialMetric", "name": "Net Sales", "properties": {"percentage_direct": 38, "percentage_indirect": 62}},
#         {"id": "competition", "type": "Market", "name": "Competitive Market", "properties": {"description": "Characterized by aggressive price competition"}},
#         {"id": "intellectual_property", "type": "LegalAspect", "name": "Intellectual Property", "properties": {"description": "Protection against imitation of products"}}
#     ],
#     "relationships": [
#         {"source": "apple", "target": "third_party_carriers", "type": "DistributesThrough", "properties": {"details": "Utilizes for product distribution"}},
#         {"source": "apple", "target": "wholesalers", "type": "DistributesThrough", "properties": {"details": "Utilizes for product distribution"}},
#         {"source": "apple", "target": "retailers", "type": "DistributesThrough", "properties": {"details": "Utilizes for product distribution"}},
#         {"source": "apple", "target": "resellers", "type": "DistributesThrough", "properties": {"details": "Utilizes for product distribution"}},
#         {"source": "apple", "target": "net_sales", "type": "Generates", "properties": {"details": "Total net sales through distribution channels"}},
#         {"source": "apple", "target": "competition", "type": "CompetesIn", "properties": {"details": "Operates in a highly competitive market"}},
#         {"source": "apple", "target": "intellectual_property", "type": "Protects", "properties": {"details": "Against infringement by competitors"}}
#     ]
# }
# Found 8 entities and 7 relationships
# Processing chunk 13/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 5, 'page_label': '6'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company focused on innovative products and services"}},
#         {"id": "smartphones", "type": "Business Unit", "name": "Smartphones", "properties": {"description": "Market segment for mobile devices"}},
#         {"id": "personal_computers", "type": "Business Unit", "name": "Personal Computers", "properties": {"description": "Market segment for computing devices"}},
#         {"id": "tablets", "type": "Business Unit", "name": "Tablets", "properties": {"description": "Market segment for portable touchscreen devices"}},
#         {"id": "wearables", "type": "Business Unit", "name": "Wearables", "properties": {"description": "Market segment for wearable technology"}},
#         {"id": "accessories", "type": "Business Unit", "name": "Accessories", "properties": {"description": "Market segment for supplementary products"}},
#         {"id": "services", "type": "Business Unit", "name": "Services", "properties": {"description": "Market segment for software and support services"}},
#         {"id": "competitors", "type": "Company", "name": "Competitors", "properties": {"description": "Other companies in the technology market"}},
#         {"id": "third_party_software", "type": "Ecosystem", "name": "Third-Party Software", "properties": {"description": "Ecosystem of software applications and accessories"}},
#         {"id": "environmental_initiatives", "type": "Initiative", "name": "Environmental Initiatives", "properties": {"description": "Company's efforts towards sustainability and environmental responsibility"}},
#         {"id": "regulations", "type": "Compliance", "name": "Regulations", "properties": {"description": "Legal requirements and standards the company must adhere to"}}
#     ],
#     "relationships": [
#         {"source": "apple", "target": "smartphones", "type": "Focuses On", "properties": {"details": "Expanding market opportunities in smartphones"}},
#         {"source": "apple", "target": "personal_computers", "type": "Focuses On", "properties": {"details": "Expanding market opportunities in personal computers"}},
#         {"source": "apple", "target": "tablets", "type": "Focuses On", "properties": {"details": "Expanding market opportunities in tablets"}},
#         {"source": "apple", "target": "wearables", "type": "Focuses On", "properties": {"details": "Expanding market opportunities in wearables"}},
#         {"source": "apple", "target": "accessories", "type": "Focuses On", "properties": {"details": "Expanding market opportunities in accessories"}},
#         {"source": "apple", "target": "services", "type": "Focuses On", "properties": {"details": "Expanding market opportunities in services"}},
#         {"source": "apple", "target": "competitors", "type": "Competes With", "properties": {"details": "Facing substantial competition from other companies"}},
#         {"source": "apple", "target": "third_party_software", "type": "Relies On", "properties": {"details": "Strong third-party software and accessories ecosystem"}},
#         {"source": "apple", "target": "environmental_initiatives", "type": "Engages In", "properties": {"details": "Initiatives for sustainability and environmental responsibility"}},
#         {"source": "apple", "target": "regulations", "type": "Complies With", "properties": {"details": "Adhering to legal requirements and standards"}}
#     ]
# }
# Found 11 entities and 10 relationships
# Processing chunk 14/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 5, 'page_label': '6'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company"}},
#         {"id": "components", "type": "Component", "name": "Components", "properties": {"description": "Essential parts for products"}},
#         {"id": "smartphones", "type": "Product", "name": "Smartphones", "properties": {"description": "Mobile devices"}},
#         {"id": "personal_computers", "type": "Product", "name": "Personal Computers", "properties": {"description": "Computing devices"}},
#         {"id": "tablets", "type": "Product", "name": "Tablets", "properties": {"description": "Portable touchscreen devices"}},
#         {"id": "wearables", "type": "Product", "name": "Wearables", "properties": {"description": "Smart wearable technology"}},
#         {"id": "accessories", "type": "Product", "name": "Accessories", "properties": {"description": "Additional products for devices"}},
#         {"id": "custom_components", "type": "Component", "name": "Custom Components", "properties": {"description": "Unique components not commonly used by competitors"}},
#         {"id": "competitors", "type": "Company", "name": "Competitors", "properties": {"description": "Other companies in the technology market"}}
#     ],
#     "relationships": [
#         {"source": "apple", "target": "components", "type": "Uses", "properties": {"details": "Essential for product manufacturing"}},
#         {"source": "apple", "target": "smartphones", "type": "Produces", "properties": {"details": "Includes iPhones"}},
#         {"source": "apple", "target": "personal_computers", "type": "Produces", "properties": {"details": "Includes MacBooks"}},
#         {"source": "apple", "target": "tablets", "type": "Produces", "properties": {"details": "Includes iPads"}},
#         {"source": "apple", "target": "wearables", "type": "Produces", "properties": {"details": "Includes Apple Watch"}},
#         {"source": "apple", "target": "accessories", "type": "Produces", "properties": {"details": "Includes AirPods"}},
#         {"source": "apple", "target": "custom_components", "type": "Uses", "properties": {"details": "Available from limited sources"}},
#         {"source": "apple", "target": "competitors", "type": "Competes", "properties": {"details": "In various product markets"}}
#     ]
# }
# Found 9 entities and 8 relationships
# Processing chunk 15/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 5, 'page_label': '6'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company"}},
#         {"id": "suppliers", "type": "Supplier", "name": "Various Suppliers", "properties": {"description": "Suppliers of custom components"}},
#         {"id": "r_and_d", "type": "Business Unit", "name": "Research and Development", "properties": {"description": "Focuses on developing new technologies and products"}},
#         {"id": "intellectual_property", "type": "Intellectual Property", "name": "Intellectual Property Rights", "properties": {"description": "Collection of rights related to hardware technologies"}}
#     ],
#     "relationships": [
# ...
#     ],
#     "relationships": [
#         {"source": "apple", "target": "suppliers", "type": "Outsources", "properties": {"details": "Manufacturing performed by outsourcing partners", "dependency_level": "High"}},
#         {"source": "apple", "target": "logistics_providers", "type": "WorksWith", "properties": {"details": "Logistics for distribution of products", "dependency_level": "Medium"}},
#         {"source": "apple", "target": "distributors", "type": "SellsThrough", "properties": {"details": "Distributors for product sales", "dependency_level": "High"}},
#         {"source": "apple", "target": "cellular_network_carriers", "type": "PartnersWith", "properties": {"details": "Cellular services for products", "dependency_level": "Medium"}},
#         {"source": "suppliers", "target": "china", "type": "LocatedIn", "properties": {"details": "Manufacturing primarily in China", "importance": "Critical"}},
#         {"source": "suppliers", "target": "india", "type": "LocatedIn", "properties": {"details": "Manufacturing in India", "importance": "Moderate"}},
#         {"source": "suppliers", "target": "japan", "type": "LocatedIn", "properties": {"details": "Manufacturing in Japan", "importance": "Moderate"}},
#         {"source": "suppliers", "target": "south_korea", "type": "LocatedIn", "properties": {"details": "Manufacturing in South Korea", "importance": "Moderate"}},
#         {"source": "suppliers", "target": "taiwan", "type": "LocatedIn", "properties": {"details": "Manufacturing in Taiwan", "importance": "Moderate"}},
#         {"source": "suppliers", "target": "vietnam", "type": "LocatedIn", "properties": {"details": "Manufacturing in Vietnam", "importance": "Moderate"}}
#     ]
# }
# Found 11 entities and 10 relationships
# Processing chunk 26/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 8, 'page_label': '9'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company"}},
#         {"id": "us", "type": "Country", "name": "United States", "properties": {"description": "Country involved in trade tensions"}},
#         {"id": "china", "type": "Country", "name": "China", "properties": {"description": "Country involved in trade tensions"}},
#         {"id": "suppliers", "type": "Business Unit", "name": "Suppliers and Contract Manufacturers", "properties": {"description": "Entities providing components and manufacturing services"}},
#         {"id": "tariffs", "type": "Regulation", "name": "Tariffs", "properties": {"description": "Trade restrictions affecting business operations"}},
#         {"id": "supply_chain", "type": "Business Unit", "name": "Supply Chain Operations", "properties": {"description": "Operations related to sourcing and logistics"}},
#         {"id": "components", "type": "Product", "name": "Components and Raw Materials", "properties": {"description": "Materials used in products"}}
#     ],
#     "relationships": [
#         {"source": "apple", "target": "suppliers", "type": "Works With", "properties": {"details": "Collaborates with suppliers for product components"}},
#         {"source": "apple", "target": "us", "type": "Operates In", "properties": {"details": "Has significant operations in the United States"}},
#         {"source": "apple", "target": "china", "type": "Operates In", "properties": {"details": "Has significant operations in China"}},
#         {"source": "us", "target": "china", "type": "Trade Relationship", "properties": {"details": "Tensions affecting trade and tariffs"}},
#         {"source": "apple", "target": "tariffs", "type": "Affected By", "properties": {"details": "Business operations impacted by tariffs"}},
#         {"source": "apple", "target": "supply_chain", "type": "Relies On", "properties": {"details": "Dependent on supply chain operations for product delivery"}},
#         {"source": "components", "target": "apple", "type": "Used In", "properties": {"details": "Components and raw materials are used in Apple's products"}}
#     ]
# }
# Found 7 entities and 7 relationships
# Processing chunk 27/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 8, 'page_label': '9'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company"}},
#         {"id": "suppliers", "type": "Business Unit", "name": "Suppliers and Contract Manufacturers", "properties": {"description": "Entities that provide components and manufacturing services"}},
#         {"id": "natural_disasters", "type": "Risk Factor", "name": "Natural Disasters", "properties": {"description": "Events like earthquakes and extreme weather affecting operations"}},
#         {"id": "climate_change", "type": "Environmental Factor", "name": "Global Climate Change", "properties": {"description": "Affects frequency and intensity of natural disasters"}},
#         {"id": "geopolitical_tensions", "type": "Risk Factor", "name": "Geopolitical Tensions", "properties": {"description": "Can disrupt global supply chains"}},
#         {"id": "industrial_accidents", "type": "Risk Factor", "name": "Industrial Accidents", "properties": {"description": "Accidents at suppliers and manufacturers"}},
#         {"id": "cybersecurity_attacks", "type": "Risk Factor", "name": "Cybersecurity Attacks", "properties": {"description": "Threats like ransomware affecting operations"}},
#         {"id": "consumer_spending", "type": "Economic Factor", "name": "Consumer Spending", "properties": {"description": "Impacted by disruptions in operations"}}
#     ],
#     "relationships": [
#         {"source": "apple", "target": "suppliers", "type": "Operates With", "properties": {"details": "Collaborates with suppliers for manufacturing and components"}},
#         {"source": "suppliers", "target": "natural_disasters", "type": "Affected By", "properties": {"details": "Operations are prone to natural disasters"}},
#         {"source": "suppliers", "target": "industrial_accidents", "type": "Risk Of", "properties": {"details": "Subject to industrial accidents"}},
#         {"source": "apple", "target": "climate_change", "type": "Impacted By", "properties": {"details": "Operations affected by climate change"}},
#         {"source": "apple", "target": "geopolitical_tensions", "type": "Vulnerable To", "properties": {"details": "Supply chains can be disrupted by geopolitical tensions"}},
#         {"source": "apple", "target": "cybersecurity_attacks", "type": "Threatened By", "properties": {"details": "Operations can be affected by cybersecurity threats"}},
#         {"source": "apple", "target": "consumer_spending", "type": "Impacted By", "properties": {"details": "Disruptions can negatively affect consumer spending"}}
#     ]
# }
# Found 8 entities and 7 relationships
# Processing chunk 28/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 8, 'page_label': '9'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company", "business_units": ["Consumer Electronics", "Software", "Services"]}},
#         {"id": "suppliers", "type": "Supplier", "name": "Various Suppliers", "properties": {"description": "Contract manufacturers and suppliers", "risk_level": "High"}},
#         {"id": "covid19", "type": "Event", "name": "COVID-19 Pandemic", "properties": {"description": "Major public health issue affecting operations"}},
#         {"id": "components", "type": "Component", "name": "Critical Components", "properties": {"description": "Key components for products", "dependency_level": "High"}},
#         {"id": "geographic_locations", "type": "Location", "name": "Global Operations", "properties": {"description": "Operations across various regions"}},
#         {"id": "environmental_initiatives", "type": "Initiative", "name": "Environmental Initiatives", "properties": {"description": "Efforts to maintain safe working environments"}},
#         {"id": "regulations", "type": "Regulation", "name": "Public Safety Regulations", "properties": {"description": "Regulations affecting operations and supply chain"}}
#     ],
#     "relationships": [
#         {"source": "suppliers", "target": "apple", "type": "Supplies", "properties": {"details": "Provide critical components and manufacturing services", "dependency_level": "High"}},
#         {"source": "covid19", "target": "apple", "type": "Affects", "properties": {"details": "Adversely affects operations and demand for products"}},
#         {"source": "components", "target": "apple", "type": "Used In", "properties": {"details": "Used in the production of Apple products"}},
#         {"source": "geographic_locations", "target": "apple", "type": "Operates In", "properties": {"details": "Apple operates globally across various regions"}},
#         {"source": "environmental_initiatives", "target": "suppliers", "type": "Requires", "properties": {"details": "Suppliers must maintain safe working environments"}},
#         {"source": "regulations", "target": "apple", "type": "Subject To", "properties": {"details": "Apple's operations are subject to public safety regulations"}}
#     ]
# }
# Found 7 entities and 6 relationships
# Processing chunk 29/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 8, 'page_label': '9'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company"}},
#         {"id": "insurance", "type": "Financial Instrument", "name": "Insurance Coverage", "properties": {"description": "Coverage for certain types of losses"}},
#         {"id": "components", "type": "Product Category", "name": "Critical Components", "properties": {"description": "Essential parts for manufacturing"}}
#     ],
#     "relationships": [
#         {"source": "components", "target": "apple", "type": "Used In", "properties": {"details": "Critical for operations", "impact": "Negative consequences if interrupted"}},
#         {"source": "insurance", "target": "apple", "type": "Covers", "properties": {"details": "Certain types of losses", "coverage_level": "Insufficient for all losses"}}
#     ]
# }
# Found 3 entities and 2 relationships
# Processing chunk 30/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 9, 'page_label': '10'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company", "focus": "Consumer electronics, software, and services"}},
#         {"id": "r_and_d", "type": "Business Unit", "name": "Research and Development", "properties": {"description": "Investments in innovation and product development"}},
#         {"id": "patents", "type": "Intellectual Property", "name": "Patents, Trademarks, and Copyrights", "properties": {"description": "Legal protections for innovations and branding"}},
#         {"id": "global_markets", "type": "Market", "name": "Global Markets", "properties": {"description": "Highly competitive markets for products and services"}}
#     ],
#     "relationships": [
#         {"source": "apple", "target": "r_and_d", "type": "Invests In", "properties": {"details": "Significant investments in R&D for product innovation"}},
#         {"source": "apple", "target": "patents", "type": "Holds", "properties": {"details": "Significant number of patents, trademarks, and copyrights"}},
#         {"source": "apple", "target": "global_markets", "type": "Operates In", "properties": {"details": "Competes in highly competitive global markets"}}
#     ]
# }
# Found 4 entities and 3 relationships
# Processing chunk 31/550
# Processing chunk with metadata: {'producer': 'Wdesk Fidelity Content Translations Version 010.004.252', 'creator': 'Workiva', 'creationdate': '2024-10-31T19:17:25+00:00', 'author': 'anonymous', 'moddate': '2024-10-31T14:07:33-07:00', 'title': '10-K 2024, 09.28.2024-2024-10-31-12-16', 'source': '/Users/sreekargudipati/Coding Projects/CompanyMapper/documents/apple_10K_2024_annualreport.pdf', 'total_pages': 121, 'page': 9, 'page_label': '10'}
# LLM initialized
# Chain initialized
# LLM output: {
#     "entities": [
#         {"id": "apple", "type": "Company", "name": "Apple Inc.", "properties": {"description": "Technology company", "market_share": "minority in global smartphone, personal computer, and tablet markets"}},
#         {"id": "intellectual_property", "type": "Legal Asset", "name": "Intellectual Property", "properties": {"description": "Patents, trademarks, and copyrights held by Apple"}},
#         {"id": "competitors", "type": "Company", "name": "Competitors", "properties": {"description": "Companies competing with Apple through pricing and imitation"}},
#         {"id": "smartphone_market", "type": "Market", "name": "Global Smartphone Market", "properties": {"description": "Market for smartphones where Apple has a minority share"}},
#         {"id": "pc_market", "type": "Market", "name": "Personal Computer Market", "properties": {"description": "Market for personal computers where Apple has a minority share"}},
#         {"id": "tablet_market", "type": "Market", "name": "Tablet Market", "properties": {"description": "Market for tablets where Apple has a minority share"}}
#     ],
#     "relationships": [
#         {"source": "apple", "target": "intellectual_property", "type": "Holds", "properties": {"details": "Significant number of patents, trademarks, and copyrights"}},
#         {"source": "competitors", "target": "apple", "type": "Competes Against", "properties": {"details": "Competes through aggressive pricing and imitation"}},
#         {"source": "apple", "target": "smartphone_market", "type": "Operates In", "properties": {"details": "Minority market share"}},
#         {"source": "apple", "target": "pc_market", "type": "Operates In", "properties": {"details": "Minority market share"}},
#         {"source": "apple", "target": "tablet_market", "type": "Operates In", "properties": {"details": "Minority market share"}}
#     ]
# }
# Found 6 entities and 5 relationships
# Processed 30 chunks, stopping for now.

# %%
print(knowledge_graph['entities'][8])
# Out:
# {'id': 'notes_due_2029_2', 'type': 'FinancialInstrument', 'name': '3.050% Notes due 2029', 'properties': {}}

# %%
def create_networkx_graph(knowledge_graph: Dict[str, Any]) -> nx.DiGraph:
    G = nx.DiGraph()
    
    for entity in knowledge_graph["entities"]:
        attributes = {
            "type": entity["type"],
            "name": entity["name"],
        }
        
        for prop_key, prop_value in entity["properties"].items():
            attributes[f"prop_{prop_key}"] = prop_value
            
        if "source" in entity:
            attributes["source"] = entity["source"]
            
        G.add_node(entity["id"], **attributes)
    
    for rel in knowledge_graph["relationships"]:
        if rel["source"] not in G or rel["target"] not in G:
            continue
            
        rel_key = (rel["source"], rel["target"], rel["type"])
        
        attributes = {
            "type": rel["type"],
        }
        
        for prop_key, prop_value in rel["properties"].items():
            attributes[f"prop_{prop_key}"] = prop_value
            
        G.add_edge(rel["source"], rel["target"], **attributes)
    
    return G

# %%
G = create_networkx_graph(knowledge_graph)

print(f"Knowledge graph created with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges")

print(G.nodes(data=True))
# Out:
# Knowledge graph created with 125 nodes and 134 edges
# [('apple', {'type': 'Company', 'name': 'Apple Inc.', 'prop_description': 'Technology company', 'prop_fiscal_year_ended': 'September 28, 2024', 'prop_headquarters': 'One Apple Park Way, Cupertino, California 95014', 'prop_fiscal_quarter_revenue': '$2,628,553,000,000', 'prop_shares_outstanding': '15,115,823,000', 'prop_fiscal_year_end': 'September 28, 2024', 'prop_business_units': ['Consumer Electronics', 'Software', 'Services'], 'prop_employees': 164000, 'prop_operations': 'International', 'prop_global_business': True, 'prop_focus': 'Consumer electronics, software, and services', 'prop_market_share': 'minority in global smartphone, personal computer, and tablet markets'}), ('california', {'type': 'GeographicLocation', 'name': 'California', 'prop_description': 'State of incorporation'}), ('nasdaq', {'type': 'StockExchange', 'name': 'The Nasdaq Stock Market LLC', 'prop_description': 'Stock exchange where Apple is listed'}), ('common_stock', {'type': 'FinancialInstrument', 'name': 'Common Stock', 'prop_par_value': '$0.00001', 'prop_trading_symbol': 'AAPL'}), ('notes_due_2025', {'type': 'FinancialInstrument', 'name': '0.000% Notes due 2025'}), ('notes_due_2026', {'type': 'FinancialInstrument', 'name': '1.625% Notes due 2026'}), ('notes_due_2027', {'type': 'FinancialInstrument', 'name': '2.000% Notes due 2027'}), ('notes_due_2029_1', {'type': 'FinancialInstrument', 'name': '1.375% Notes due 2029'}), ('notes_due_2029_2', {'type': 'FinancialInstrument', 'name': '3.050% Notes due 2029'}), ('notes_due_2031', {'type': 'FinancialInstrument', 'name': '0.500% Notes due 2031'}), ('notes_due_2042', {'type': 'FinancialInstrument', 'name': '3.600% Notes due 2042'}), ('sec', {'type': 'Regulatory Body', 'name': 'U.S. Securities and Exchange Commission', 'prop_description': 'Regulatory authority overseeing securities transactions'}), ('proxy_statement', {'type': 'Document', 'name': 'Definitive Proxy Statement', 'prop_description': 'Document related to annual meeting of shareholders', 'prop_filing_deadline': '120 days after fiscal year end'}), ('form_10k', {'type': 'Document', 'name': 'Annual Report on Form 10-K', 'prop_description': 'Annual financial report', 'prop_year': 2024}), ('macroeconomic_conditions', {'type': 'Concept', 'name': 'Macroeconomic Conditions', 'prop_description': 'Economic factors affecting business'}), ('risk_factors', {'type': 'Section', 'name': 'Risk Factors', 'prop_description': 'Potential risks affecting performance'}), ('iphone', {'type': 'Product', 'name': 'iPhone', 'prop_description': 'Line of smartphones', 'prop_operating_system': 'iOS', 'prop_models': ['iPhone 16 Pro', 'iPhone 16', 'iPhone 15', 'iPhone 14', 'iPhone SE']}), ('mac', {'type': 'Product', 'name': 'Mac', 'prop_description': 'Line of personal computers', 'prop_operating_system': 'macOS', 'prop_models': ['MacBook Air', 'MacBook Pro', 'iMac', 'Mac mini', 'Mac Studio', 'Mac Pro']}), ('ipad', {'type': 'Product', 'name': 'iPad', 'prop_description': 'Line of multipurpose tablets', 'prop_operating_system': 'iPadOS', 'prop_models': ['iPad Pro']}), ('ipad_pro', {'type': 'Product', 'name': 'iPad Pro', 'prop_description': 'High-end model of iPad'}), ('ipad_air', {'type': 'Product', 'name': 'iPad Air', 'prop_description': 'Lightweight model of iPad'}), ('ipad_mini', {'type': 'Product', 'name': 'iPad mini', 'prop_description': 'Compact model of iPad'}), ('wearables', {'type': 'Business Unit', 'name': 'Wearables', 'prop_description': 'Smart wearable technology'}), ('apple_watch', {'type': 'Product', 'name': 'Apple Watch', 'prop_description': 'Line of smartwatches', 'prop_operating_system': 'watchOS'}), ('apple_watch_ultra_2', {'type': 'Product', 'name': 'Apple Watch Ultra 2', 'prop_description': 'Premium smartwatch model'}), ('apple_watch_series_10', {'type': 'Product', 'name': 'Apple Watch Series 10', 'prop_description': 'Latest series of Apple Watch'}), ('apple_watch_se', {'type': 'Product', 'name': 'Apple Watch SE', 'prop_description': 'Affordable smartwatch model'}),  ...
# [('apple', 'california', {'type': 'IncorporatedIn', 'prop_details': 'Apple Inc. is incorporated in California'}), ('apple', 'sec', {'type': 'Files Reports', 'prop_details': 'Files annual and quarterly reports with the SEC'}), ('apple', 'proxy_statement', {'type': 'Incorporates', 'prop_details': 'Incorporated by reference in annual report'}), ('apple', 'applecare', {'type': 'Offers', 'prop_details': 'Provides priority access to technical support and repair services'}), ('apple', 'cloud_services', {'type': 'Offers', 'prop_details': 'Stores and keeps customers’ content up-to-date'}), ('apple', 'digital_content', {'type': 'Operates', 'prop_details': 'Platforms for discovering and downloading applications and digital content'}), ('apple', 'payment_services', {'type': 'Offers', 'prop_details': 'Includes Apple Card and Apple Pay'}), ('apple', 'apple_card', {'type': 'Offers', 'prop_details': 'Co-branded credit card service'}), ('apple', 'apple_pay', {'type': 'Offers', 'prop_details': 'Cashless payment service'}), ('apple', 'americas', {'type': 'OperatesIn', 'prop_details': 'Geographic segment for operations'}), ('apple', 'europe', {'type': 'OperatesIn', 'prop_details': 'Geographic segment for operations'}), ('apple', 'greater_china', {'type': 'OperatesIn', 'prop_details': 'Geographic segment for operations'}), ('apple', 'rest_asia_pacific', {'type': 'OperatesIn', 'prop_details': 'Geographic segment for operations'}), ('apple', 'consumer_market', {'type': 'Serves', 'prop_details': 'Primary customer segment'}), ('apple', 'education_market', {'type': 'Serves', 'prop_details': 'Primary customer segment'}), ('apple', 'enterprise_market', {'type': 'Serves', 'prop_details': 'Primary customer segment'}), ('apple', 'government_market', {'type': 'Serves', 'prop_details': 'Primary customer segment'}), ('apple', 'small_mid_business', {'type': 'Serves', 'prop_details': 'Primary customer segment'}), ('apple', 'third_party_carriers', {'type': 'DistributesThrough', 'prop_details': 'Utilizes for product distribution'}), ('apple', 'wholesalers', {'type': 'DistributesThrough', 'prop_details': 'Utilizes for product distribution'}), ('apple', 'retailers', {'type': 'DistributesThrough', 'prop_details': 'Utilizes for product distribution'}), ('apple', 'resellers', {'type': 'DistributesThrough', 'prop_details': 'Utilizes for product distribution'}), ('apple', 'net_sales', {'type': 'Generates', 'prop_details': 'Total net sales through distribution channels'}), ('apple', 'competition', {'type': 'CompetesIn', 'prop_details': 'Operates in a highly competitive market'}), ('apple', 'intellectual_property', {'type': 'Holds', 'prop_details': 'Significant number of patents, trademarks, and copyrights', 'prop_importance': 'Differentiates business'}), ('apple', 'smartphones', {'type': 'Produces', 'prop_details': 'Includes iPhones'}), ('apple', 'personal_computers', {'type': 'Produces', 'prop_details': 'Includes MacBooks'}), ('apple', 'tablets', {'type': 'Produces', 'prop_details': 'Includes iPads'}), ('apple', 'wearables', {'type': 'Produces', 'prop_details': 'Includes Apple Watch'}), ('apple', 'accessories', {'type': 'Produces', 'prop_details': 'Includes AirPods'}), ('apple', 'services', {'type': 'Focuses On', 'prop_details': 'Expanding market opportunities in services'}), ('apple', 'competitors', {'type': 'Competes', 'prop_details': 'In various product markets'}), ('apple', 'third_party_software', {'type': 'Relies On', 'prop_details': 'Strong third-party software and accessories ecosystem'}), ('apple', 'environmental_initiatives', {'type': 'Engages In', 'prop_details': 'Engages in environmental and social governance initiatives'}), ('apple', 'regulations', {'type': 'Complies With', 'prop_details': 'Adhering to legal requirements and standards'}), ('apple', 'components', {'type': 'Uses', 'prop_details': 'Essential for product manufacturing'}), ('apple', 'custom_components', {'type': 'Uses', 'prop_details': 'Available from limited sources'}), ('apple', 'holiday_demand' ...
